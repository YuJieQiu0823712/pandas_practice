# %% [markdown]
# # Exercise 1

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Step 2. Download the dataset to your computer and unzip it.

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is DA5D-2483
#
#  Directory of c:\Users\jade\freeCodeCamp\pandas_practice\01_Getting_and knowing_your_data
#
# 2025-02-17  02:53 PM    <DIR>          .
# 2025-02-16  11:55 PM    <DIR>          ..
# 2025-02-17  03:02 PM            16,417 Exercises 1.ipynb
# 2025-02-17  12:22 AM            34,225 Exercises 2.ipynb
# 2019-09-19  02:16 AM     1,010,256,825 openfoodfacts.tsv
#                3 File(s)  1,010,307,467 bytes
#                2 Dir(s)  414,854,320,128 bytes free

# %% [markdown]
# ### Step 3. Use the tsv file and assign it to a dataframe called food

# %%
import pandas as pd
food = pd.read_csv('openfoodfacts.tsv',sep='\t')
# Out:
# C:\Users\jade\AppData\Local\Temp\ipykernel_44368\3623544619.py:2: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   food = pd.read_csv('openfoodfacts.tsv',sep='\t')

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
pd.set_option('display.max_rows',200)

# %%
food.head(5).T
# Out:
#                                                                                             0  \
# code                                                                                     3087
# url                                         http://world-en.openfoodfacts.org/product/0000...
# creator                                                            openfoodfacts-contributors
# created_t                                                                          1474103866
# created_datetime                                                         2016-09-17T09:17:46Z
# last_modified_t                                                                    1474103893
# last_modified_datetime                                                   2016-09-17T09:18:13Z
# product_name                                                               Farine de blé noir
# generic_name                                                                              NaN
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
food.shape # 356027
# Out:
# (356027, 163)

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
food.shape # 163
# Out:
# (356027, 163)

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
for c in food.columns:
    print(c)
# Out:
# code
# url
# creator
# created_t
# created_datetime
# last_modified_t
# last_modified_datetime
# product_name
# generic_name
# quantity
# packaging
# packaging_tags
# brands
# brands_tags
# categories
# categories_tags
# categories_en
# origins
# origins_tags
# manufacturing_places
# manufacturing_places_tags
# labels
# labels_tags
# labels_en
# emb_codes
# emb_codes_tags
# first_packaging_code_geo
# cities
# cities_tags
# purchase_places
# stores
# countries
# countries_tags
# countries_en
# ingredients_text
# allergens
# allergens_en
# traces
# traces_tags
# traces_en
# serving_size
# no_nutriments
# additives_n
# additives
# additives_tags
# additives_en
# ingredients_from_palm_oil_n
# ingredients_from_palm_oil
# ingredients_from_palm_oil_tags
# ingredients_that_may_be_from_palm_oil_n
# ingredients_that_may_be_from_palm_oil
# ingredients_that_may_be_from_palm_oil_tags
# nutrition_grade_uk
# nutrition_grade_fr
# pnns_groups_1
# pnns_groups_2
# states
# states_tags
# states_en
# ...

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %%
food.columns[104]
# Out:
# '-glucose_100g'

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %%
# type(food.columns[104]) => str

# food[['-glucose_100g']].info()
food['-glucose_100g'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %%
food.index
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %%
pd.set_option?
# Out:
# Signature:   pd.set_option(*args, **kwds) -> 'T'
# Type:        CallableDynamicDoc
# String form: <pandas._config.config.CallableDynamicDoc object at 0x000002477F6A6E30>
# File:        c:\users\jade\anaconda3\envs\pytorch\lib\site-packages\pandas\_config\config.py
# Docstring:
# set_option(pat, value)
#
# Sets the value of the specified option.
#
# Available options:
#
# - compute.[use_bottleneck, use_numba, use_numexpr]
# - display.[chop_threshold, colheader_justify, date_dayfirst, date_yearfirst,
#   encoding, expand_frame_repr, float_format]
# - display.html.[border, table_schema, use_mathjax]
# - display.[large_repr, max_categories, max_columns, max_colwidth, max_dir_items,
#   max_info_columns, max_info_rows, max_rows, max_seq_items, memory_usage,
#   min_rows, multi_sparse, notebook_repr_html, pprint_nest_depth, precision,
#   show_dimensions]
# - display.unicode.[ambiguous_as_wide, east_asian_width]
# - display.[width]
# - future.[infer_string, no_silent_downcasting]
# ...

# %%
pd.set_option('display.max_colwidth',300)
food[['code','url']]
# Out:
#                  code  \
# 0                3087
# 1                4530
# 2                4559
# 3               16087
# 4               16094
# ...               ...
# 356022       99567453
# 356023  9970229501521
# 356024  9977471758307
# 356025  9980282863788
# 356026   999990026839
#
#                                                                                                                                                url
# 0                                                       http://world-en.openfoodfacts.org/product/0000000003087/farine-de-ble-noir-ferme-t-y-r-nao
# 1                                                             http://world-en.openfoodfacts.org/product/0000000004530/banana-chips-sweetened-whole
# 2                                                                     http://world-en.openfoodfacts.org/product/0000000004559/peanuts-torn-glasser
# ...

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?

# %%
# food.loc[18,'product_name']
# food.at[18, 'product_name'] 
food.values[18][7]
# Out:
# 'Lotus Organic Brown Jasmine Rice'

# %%
# iloc[]: integer-based,  Single value, Series, or DataFrame
# loc[]: label-based, Single value, Series, or DataFrame
# at[]: label-based, Single value
